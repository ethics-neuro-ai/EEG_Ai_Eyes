# %%
import pandas as pd
from src.utils import load_arff
from src.utils import load_csv, plot_eeg_signal

# %%
dataset_path = "/Volumes/backup/mail/EEG Eye State.arff"
df = load_arff(dataset_path)
df.head()

# %%
df.describe()

# %%
plot_eeg_signal(df, n_samples=500)

# %%
df['eyeState'].value_counts().plot(kind='bar', title="Distribuzione occhi aperti/chiusi")
